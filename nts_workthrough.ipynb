# %%
import name_to_struct as nts
from rdkit import Chem

smi = nts.process_msn('TPPV-N-3')
mol = Chem.MolFromSmiles(smi)
mol

# %%
cores, core_labels, core_img, ends, end_labels, end_img = nts.show_fragments()
print("Coded Core Groups")
end_img
# Out:
# Coded End Groups

# %%
print("Coded End Groups")
end_img
